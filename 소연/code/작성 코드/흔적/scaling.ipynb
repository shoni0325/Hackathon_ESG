# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/new/winsor_1.csv', encoding='euc-kr', index_col='기업명').drop('Unnamed: 0', axis=1)

# %%
from sklearn.preprocessing import StandardScaler

df_1 = df.iloc[:, 3:8]
df_1

sc = StandardScaler()

df.iloc[:, 3:8] = sc.fit_transform(df_1)
df
# Out:
#             업종명  평가연도         총자산규모      부채비율    자기자본비율    매출액증가율      현금흐름
# 기업명
# CS홀딩스      서비스업  2011  1.887535e+11 -0.367185  1.539085  0.016273  0.125672  \
# KISCO홀딩스   서비스업  2011  7.797319e+11 -0.371555  1.600118 -0.021487  0.051014
# LG이노텍      전기전자  2011  4.409967e+12  0.177533 -1.079759 -0.013113  0.093215
# MH에탄올      음식료품  2011  1.342069e+11  0.131503 -0.998226 -0.057522 -0.198769
# OCI          화학  2011  7.205013e+12 -0.171994 -0.073873  0.013542  1.346364
# ...         ...   ...           ...       ...       ...       ...       ...
# 후성           화학  2021  6.163344e+11 -0.112354 -0.336643  0.039101  0.847486
# 휠라홀딩스       유통업  2021  4.288857e+12 -0.191405  0.026296  0.002361  0.454987
# 휴비스          화학  2021  8.434152e+11 -0.205643  0.105034 -0.029547 -0.283195
# 휴스틸        철강금속  2021  9.519209e+11 -0.276734  0.586312  0.073440 -0.195590
# 흥아해운      운수창고업  2021  2.472987e+11 -0.055075 -0.539777 -0.041718 -0.375240
#
#                PBR  ESG_-  ESG_A  ...    S_D    G_-    G_A   G_A+    G_B
# 기업명                               ...
# CS홀딩스    -0.753474  False  False  ...  False  False  False  False  False  \
# KISCO홀딩스 -0.794531  False  False  ...  False  False  False  False  False
# LG이노텍     0.111887  False   True  ...  False  False   True  False  False
# MH에탄올    -0.772423  False  False  ...  False  False  False  False  False
# OCI       0.910925  False   True  ...  False  False   True  False  False
# ...            ...    ...    ...  ...    ...    ...    ...    ...    ...
# 후성        2.796402  False  False  ...  False  False  False  False   True
# 휠라홀딩스     3.175392  False   True  ...  False  False   True  False  False
# 휴비스      -0.431332  False   True  ...  False  False   True  False  False
# 휴스틸      -0.845063  False  False  ...  False  False  False  False   True
# 흥아해운      3.036429  False  False  ...  False  False  False  False  False
#
#            G_B+  G_B이하    G_C    G_D  배당기업구분
# 기업명
# CS홀딩스     False  False   True  False   무배당기업
# KISCO홀딩스  False  False   True  False   중배당기업
# LG이노텍     False  False  False  False   무배당기업
# MH에탄올     False   True  False  False   무배당기업
# OCI       False  False  False  False   중배당기업
# ...         ...    ...    ...    ...     ...
# 후성        False  False  False  False   저배당기업
# 휠라홀딩스     False  False  False  False   고배당기업
# 휴비스       False  False  False  False   저배당기업
# 휴스틸       False  False  False  False   중배당기업
# 흥아해운      False  False  False   True   무배당기업
#
# [3752 rows x 41 columns]

# %%
df.iloc[:, 3:8].describe()
# Out:
#                부채비율        자기자본비율       매출액증가율          현금흐름           PBR
# count  3.752000e+03  3.752000e+03  3752.000000  3.752000e+03  3.752000e+03
# mean  -7.575082e-18  1.780144e-16     0.000000 -1.325639e-17 -1.515016e-17
# std    1.000133e+00  1.000133e+00     1.000133  1.000133e+00  1.000133e+00
# min   -4.072379e-01 -5.831043e+00    -0.172544 -1.319431e+01 -8.450632e-01
# 25%   -3.061831e-01 -7.058715e-01    -0.034102 -1.899890e-01 -5.734535e-01
# 50%   -1.921332e-01  2.093797e-02    -0.024842  1.330803e-02 -3.302680e-01
# 75%   -6.771126e-04  8.305618e-01    -0.011041  2.383974e-01  1.118873e-01
# max    3.175472e+01  2.025488e+00    61.043500  4.229827e+01  4.688195e+00

# %%
df['총자산규모'] = np.log(df['총자산규모'])

# %%
df['총자산규모']
# Out:
# 기업명
# CS홀딩스       25.963708
# KISCO홀딩스    27.382216
# LG이노텍       29.114888
# MH에탄올       25.622648
# OCI         29.605798
#               ...
# 후성          27.147056
# 휠라홀딩스       29.087041
# 휴비스         27.460725
# 휴스틸         27.581748
# 흥아해운        26.233863
# Name: 총자산규모, Length: 3752, dtype: float64

# %%
# df.to_csv('win1_sc.csv', encoding='euc-kr')
