# %%
import pandas as pd

# %%
sum1 = pd.read_csv('../../data/new/sum1.csv', index_col='기업명')
sum1.columns = ['업종명', '평가연도', '총자산규모', '부채비율', '자기자본비율', '매출액증가율', '현금흐름', 'PBR',
       'ESG_-', 'ESG_A', 'ESG_A+', 'ESG_B', 'ESG_B+', 'ESG_B이하', 'ESG_C',
       'ESG_D', 'E_-', 'E_A', 'E_A+', 'E_B', 'E_B+', 'E_B+이하', 'E_C', 'E_D',
       'S_-', 'S_A', 'S_A+', 'S_B', 'S_B+', 'S_B이하', 'S_C', 'S_D', 'G_-',
       'G_A', 'G_A+', 'G_B', 'G_B+', 'G_B이하', 'G_C', 'G_D', '배당기업구분']
sum1
# Out:
#             업종명  평가연도         총자산규모    부채비율  자기자본비율  매출액증가율      현금흐름    PBR
# 기업명
# CS홀딩스      서비스업  2011  1.887535e+11   15.95   86.25   30.53  0.070627  0.390  \
# KISCO홀딩스   서비스업  2011  7.797319e+11   14.21   87.56    5.37  0.055293  0.325
# LG이노텍      전기전자  2011  4.409967e+12  232.87   30.04   10.95  0.063961  1.760
# MH에탄올      음식료품  2011  1.342069e+11  214.54   31.79  -18.64  0.003993  0.360
# OCI          화학  2011  7.205013e+12   93.68   51.63   28.71  0.321332  3.025
# ...         ...   ...           ...     ...     ...     ...       ...    ...
# 후성           화학  2021  6.163344e+11  117.43   45.99   45.74  0.218873  6.010
# 휠라홀딩스       유통업  2021  4.288857e+12   85.95   53.78   21.26  0.138261  6.610
# 휴비스          화학  2021  8.434152e+11   80.28   55.47    0.00 -0.013347  0.900
# 휴스틸        철강금속  2021  9.519209e+11   51.97   65.80   68.62  0.004646  0.185
# 흥아해운      운수창고업  2021  2.472987e+11  140.24   41.63   -8.11 -0.032251  6.390
#
#           ESG_-  ESG_A  ...    S_D    G_-    G_A   G_A+    G_B   G_B+  G_B이하
# 기업명                     ...
# CS홀딩스     False  False  ...  False  False  False  False  False  False  False  \
# KISCO홀딩스  False  False  ...  False  False  False  False  False  False  False
# LG이노텍     False   True  ...  False  False   True  False  False  False  False
# MH에탄올     False  False  ...  False  False  False  False  False  False   True
# OCI       False   True  ...  False  False   True  False  False  False  False
# ...         ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 후성        False  False  ...  False  False  False  False   True  False  False
# 휠라홀딩스     False   True  ...  False  False   True  False  False  False  False
# 휴비스       False   True  ...  False  False   True  False  False  False  False
# 휴스틸       False  False  ...  False  False  False  False   True  False  False
# 흥아해운      False  False  ...  False  False  False  False  False  False  False
#
#             G_C    G_D  배당기업구분
# 기업명
# CS홀딩스      True  False   무배당기업
# KISCO홀딩스   True  False  일반배당기업
# LG이노텍     False  False   무배당기업
# MH에탄올     False  False   무배당기업
# OCI       False  False  일반배당기업
# ...         ...    ...     ...
# 후성        False  False  일반배당기업
# 휠라홀딩스     False  False   고배당기업
# 휴비스       False  False  일반배당기업
# 휴스틸       False  False  일반배당기업
# 흥아해운      False   True   무배당기업
#
# [3752 rows x 41 columns]

# %%
sum2 = pd.read_csv('../../data/new/sum2.csv', index_col='기업명')
sum2.columns = ['업종명', '평가연도', '총자산규모', '부채비율', '자기자본비율', '매출액증가율', '현금흐름', 'PBR',
       'ESG_-', 'ESG_A', 'ESG_A+', 'ESG_B', 'ESG_B+', 'ESG_B이하', 'ESG_C',
       'ESG_D', 'E_-', 'E_A', 'E_A+', 'E_B', 'E_B+', 'E_B+이하', 'E_C', 'E_D',
       'S_-', 'S_A', 'S_A+', 'S_B', 'S_B+', 'S_B이하', 'S_C', 'S_D', 'G_-',
       'G_A', 'G_A+', 'G_B', 'G_B+', 'G_B이하', 'G_C', 'G_D', '배당기업구분']
sum2
# Out:
#           업종명  평가연도         총자산규모    부채비율  자기자본비율  매출액증가율      현금흐름    PBR
# 기업명
# AJ네트웍스   서비스업  2022  1.481445e+12  309.37   24.43   17.69 -0.004866  0.900  \
# BNK금융지주  기타금융  2022  6.915787e+12   29.33   77.32   36.67  0.041283  0.475
# CS홀딩스    기타금융  2022  3.641216e+11   10.20   90.75   10.22  0.015957  0.465
# DB금융투자     증권  2022  7.096049e+12  747.40   11.80  -15.51  0.092504  0.285
# DB손해보험     보험  2022  5.049120e+13  899.79   10.00    9.87  0.089442  0.950
# ...       ...   ...           ...     ...     ...     ...       ...    ...
# 현대퓨처넷    서비스업  2022  9.152565e+11    8.32   92.32   12.81 -0.661239  0.480
# 현대홈쇼핑     유통업  2022  2.782028e+12   42.03   70.41   -4.90  0.000051  0.435
# 혜인        유통업  2022  2.405221e+11  122.61   44.92  -13.73  0.036779  1.055
# 호전실업     섬유의복  2022  3.160981e+11  133.26   42.87   39.18  0.144248  0.810
# 호텔신라      유통업  2022  2.938545e+12  444.39   18.37   30.24  0.017685  6.265
#
#          ESG_-  ESG_A  ...    S_D    G_-    G_A   G_A+    G_B   G_B+  G_B이하
# 기업명                    ...
# AJ네트웍스   False  False  ...  False  False  False  False  False   True  False  \
# BNK금융지주  False   True  ...  False  False   True  False  False  False  False
# CS홀딩스    False  False  ...   True  False  False  False   True  False  False
# DB금융투자   False  False  ...  False  False  False  False   True  False  False
# DB손해보험   False  False  ...  False  False  False  False  False   True  False
# ...        ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 현대퓨처넷    False   True  ...  False  False   True  False  False  False  False
# 현대홈쇼핑    False   True  ...  False  False   True  False  False  False  False
# 혜인       False  False  ...   True  False  False  False  False  False  False
# 호전실업     False  False  ...   True  False  False  False  False  False  False
# 호텔신라     False   True  ...  False  False   True  False  False  False  False
#
#            G_C    G_D  배당기업구분
# 기업명
# AJ네트웍스   False  False  일반배당기업
# BNK금융지주  False  False  일반배당기업
# CS홀딩스    False  False  일반배당기업
# DB금융투자   False  False  일반배당기업
# DB손해보험   False  False   고배당기업
# ...        ...    ...     ...
# 현대퓨처넷    False  False  일반배당기업
# 현대홈쇼핑    False  False   고배당기업
# 혜인       False   True  일반배당기업
# 호전실업      True  False   고배당기업
# 호텔신라     False  False  일반배당기업
#
# [536 rows x 41 columns]

# %%
sum = pd.concat([sum1, sum2], axis=0)
sum
# Out:
#            업종명  평가연도         총자산규모    부채비율  자기자본비율  매출액증가율      현금흐름    PBR
# 기업명
# CS홀딩스     서비스업  2011  1.887535e+11   15.95   86.25   30.53  0.070627  0.390  \
# KISCO홀딩스  서비스업  2011  7.797319e+11   14.21   87.56    5.37  0.055293  0.325
# LG이노텍     전기전자  2011  4.409967e+12  232.87   30.04   10.95  0.063961  1.760
# MH에탄올     음식료품  2011  1.342069e+11  214.54   31.79  -18.64  0.003993  0.360
# OCI         화학  2011  7.205013e+12   93.68   51.63   28.71  0.321332  3.025
# ...        ...   ...           ...     ...     ...     ...       ...    ...
# 현대퓨처넷     서비스업  2022  9.152565e+11    8.32   92.32   12.81 -0.661239  0.480
# 현대홈쇼핑      유통업  2022  2.782028e+12   42.03   70.41   -4.90  0.000051  0.435
# 혜인         유통업  2022  2.405221e+11  122.61   44.92  -13.73  0.036779  1.055
# 호전실업      섬유의복  2022  3.160981e+11  133.26   42.87   39.18  0.144248  0.810
# 호텔신라       유통업  2022  2.938545e+12  444.39   18.37   30.24  0.017685  6.265
#
#           ESG_-  ESG_A  ...    S_D    G_-    G_A   G_A+    G_B   G_B+  G_B이하
# 기업명                     ...
# CS홀딩스     False  False  ...  False  False  False  False  False  False  False  \
# KISCO홀딩스  False  False  ...  False  False  False  False  False  False  False
# LG이노텍     False   True  ...  False  False   True  False  False  False  False
# MH에탄올     False  False  ...  False  False  False  False  False  False   True
# OCI       False   True  ...  False  False   True  False  False  False  False
# ...         ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 현대퓨처넷     False   True  ...  False  False   True  False  False  False  False
# 현대홈쇼핑     False   True  ...  False  False   True  False  False  False  False
# 혜인        False  False  ...   True  False  False  False  False  False  False
# 호전실업      False  False  ...   True  False  False  False  False  False  False
# 호텔신라      False   True  ...  False  False   True  False  False  False  False
#
#             G_C    G_D  배당기업구분
# 기업명
# CS홀딩스      True  False   무배당기업
# KISCO홀딩스   True  False  일반배당기업
# LG이노텍     False  False   무배당기업
# MH에탄올     False  False   무배당기업
# OCI       False  False  일반배당기업
# ...         ...    ...     ...
# 현대퓨처넷     False  False  일반배당기업
# 현대홈쇼핑     False  False   고배당기업
# 혜인        False   True  일반배당기업
# 호전실업       True  False   고배당기업
# 호텔신라      False  False  일반배당기업
#
# [4288 rows x 41 columns]

# %%
# sum.to_csv('total_data.csv')

# %% [markdown]
# ### train-test

# %%
from sklearn.model_selection import train_test_split

# %%
# X = sum.iloc[:, 2:40]
# y = sum['배당기업구분']

# %%
sum_train,sum_test = train_test_split(sum, test_size=0.2, shuffle=True, random_state=0)

# %%
# sum_train.to_csv('total_train_data.csv')
# sum_test.to_csv('total_test_data.csv')
