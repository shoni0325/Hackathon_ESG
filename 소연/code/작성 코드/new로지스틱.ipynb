# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import train_test_split
import pandas as pd

# %%
train['배당기업구분'].value_counts()
# Out:
# 배당기업구분
# 중배당기업    1249
# 무배당기업     975
# 저배당기업     686
# 고배당기업     506
# Name: count, dtype: int64

# %% [markdown]
# 무배당 있고, ESG 포함

# %%
train=pd.read_csv('../../data/new/진짜최종데이터/real_sca_mm_train.csv',encoding='euc-kr',index_col='Unnamed: 0')

lg_clf=LogisticRegression(penalty='l2',C=0.07, max_iter=300,multi_class='multinomial',solver='lbfgs')

x=train.iloc[:,2:32].values
y=train['배당기업구분'].map({
    '고배당기업': 2,
    '일반배당기업':1,
    '무배당기업':0
})

X_train, X_test, y_train, y_test = train_test_split(x,y, stratify=y, test_size=0.2, random_state=0)

lg_clf.fit(X_train, y_train)
pred = lg_clf.predict(X_test)

# params={
#     'penalty':['l1','l2'],
#     'C':[5.0, 6.0, 7.0, 8.0, 10.0 ],
#     'max_iter':[100,300,500,1000]
# }

# grid=GridSearchCV(lg_clf,param_grid=params,scoring='accuracy',cv=3)
# grid.fit(X_train,y_train)

print(f'최적 하이퍼 파라미터 : {grid.best_params_}, 최적 평균 정확도 : {grid.best_score_:.3f}')
print(classification_report(y_test,pred))
# Out:
# 최적 하이퍼 파라미터 : {'C': 6.0, 'max_iter': 300, 'penalty': 'l2'}, 최적 평균 정확도 : 0.651
#               precision    recall  f1-score   support
#
#            0       0.65      0.41      0.50       195
#            1       0.62      0.88      0.73       388
#            2       0.36      0.04      0.07       101
#
#     accuracy                           0.62       684
#    macro avg       0.55      0.44      0.43       684
# weighted avg       0.59      0.62      0.57       684

# %% [markdown]
# 무배당 있고, ESG 미포함

# %%
train_2 = train.iloc[:,0:8]
train_2['배당기업구분'] = train['배당기업구분']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import train_test_split
import pandas as pd


lg_clf=LogisticRegression(penalty='l2',C=0.05, max_iter=300,multi_class='multinomial',solver='lbfgs')

X= train_2.iloc[:,2:8]
y=train['배당기업구분'].map({
    '고배당기업': 2,
    '일반배당기업':1,
    '무배당기업':0
})





X_train ,X_test ,y_train ,y_test= train_test_split(X,y,test_size=0.2,random_state=0)

lg_clf.fit(X_train, y_train)
pred = lg_clf.predict(X_test)


# params={
#     'penalty':['l1','l2'],
#     'C':[0.1,1.0,3.0],
#     'max_iter':[100,150,300,1000]
# }

# grid=GridSearchCV(lg_clf,param_grid=params,scoring='accuracy',cv=3)
# grid.fit(X_train,y_train)

# model.fit(X_train, y_train)

print(f'최적 하이퍼 파라미터 : {grid.best_params_}, 최적 평균 정확도 : {grid.best_score_:.3f}')
print(classification_report(y_test,pred))

# y_pred = model.predict(X_test) # 예측 라벨(0과 1로 예측)

# # 예측 라벨과 실제 라벨 사이의 정확도 측정
# accuracy_score(y_pred, y_test)
# Out:
# 최적 하이퍼 파라미터 : {'C': 6.0, 'max_iter': 300, 'penalty': 'l2'}, 최적 평균 정확도 : 0.651
#               precision    recall  f1-score   support
#
#            0       0.73      0.18      0.29       196
#            1       0.58      0.96      0.72       379
#            2       0.71      0.05      0.09       109
#
#     accuracy                           0.59       684
#    macro avg       0.67      0.40      0.37       684
# weighted avg       0.64      0.59      0.50       684

# %% [markdown]
# Test

# %%
train=pd.read_csv('../../data/new/진짜최종데이터/real_sca_mm_train.csv',encoding='euc-kr',index_col='Unnamed: 0')
test = pd.read_csv('../../data/new/진짜최종데이터/real_sca_mm_test.csv', encoding='euc-kr', index_col='Unnamed: 0')

# %%
test.iloc[:, 2:32]
# Out:
#          총자산규모(Size)  부채비율(DEB)  자기자본비율(DEB)    매출액증가율  현금흐름(CF)       PBR
# 무림페이퍼      28.275258   0.017513     0.610805  0.165870  0.225296  0.175681  \
# 아이에스동서     27.729239   0.014116     0.639210  0.279288  0.210756  0.193341
# 일진전기       27.454215   0.012574     0.655221  0.261748  0.210162  0.186902
# 동성제약       25.548191   0.008436     0.713159  0.197697  0.206368  0.178808
# 성안         26.283695   0.013150     0.648995  0.135146  0.219246  0.189110
# ...              ...        ...          ...       ...       ...       ...
# 대원전선       26.091444   0.012950     0.651130  0.191813  0.212987  0.232708
# 사조대림       27.245497   0.009891     0.689735  0.182109  0.213981  0.189662
# 삼화전기       25.687396   0.021249     0.587203  0.181458  0.207297  0.193341
# 한국콜마홀딩스    27.339141   0.007134     0.738066  0.309163  0.221836  0.304268
# 디아이씨       27.197517   0.027737     0.557967  0.222763  0.217865  0.255887
#
# ...

# %%
# C = 0.1
X= test.iloc[:,2:32]
y=test['배당기업구분'].map({
    '고배당기업': 2,
    '일반배당기업':1,
    '무배당기업':0
})


pred = lg_clf.predict(X)
print('RF 정확도:{0:.20f}'.format(accuracy_score(y, pred)))
# Out:
# RF 정확도:0.58665105386416860345

# %%
# C = 0.05
X= test.iloc[:,2:32]
y=test['배당기업구분'].map({
    '고배당기업': 2,
    '일반배당기업':1,
    '무배당기업':0
})


pred = lg_clf.predict(X)
print('RF 정확도:{0:.20f}'.format(accuracy_score(y, pred)))
# Out:
# RF 정확도:0.59367681498829039111

# %%
# C = 0.07
X= test.iloc[:,2:32]
y=test['배당기업구분'].map({
    '고배당기업': 2,
    '일반배당기업':1,
    '무배당기업':0
})


pred = lg_clf.predict(X)
print('RF 정확도:{0:.20f}'.format(accuracy_score(y, pred)))
# Out:
# RF 정확도:0.59367681498829039111

# %%
# C = 0.07
X= test.iloc[:,2:8]
y=test['배당기업구분'].map({
    '고배당기업': 2,
    '일반배당기업':1,
    '무배당기업':0
})


pred = lg_clf.predict(X)
print('RF 정확도:{0:.20f}'.format(accuracy_score(y, pred)))
# Out:
# RF 정확도:0.59367681498829039111
