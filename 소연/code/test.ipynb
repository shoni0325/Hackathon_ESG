# %%
data = soup.find_all('span')  # 크롤링한 데이터
text_list = [item.text for item in data]  # 텍스트 추출
print(text_list)

# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://esg.krx.co.kr/contents/02/02020000/ESG02020000.jsp"
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup = BeautifulSoup(response.text, "lxml")
cartoonsBox = soup.find('ol', attrs={"data-value": ""}) # 전체 영역에서 'a' 태그를 찾지 않고 인기 급상승 영역으로 범위 제한
cartoons = cartoonsBox.find_all('a') # 인기 급상승 영역에서 'a'태그 모두 찾아 변수 cartoons에 할당

# %%
data_list = soup.find_all('name')

# %%
data_list
# Out:
# [<span class="icon"></span>,
#  <span class="logo" onclick="$.movePage('/');"></span>,
#  <span class="title">
#  <a href="/index.jsp"></a>
#  </span>,
#  <span>ESG 소개</span>,
#  <span>ESG 기업정보</span>,
#  <span>ESG 통계</span>,
#  <span>ESG 뉴스</span>,
#  <span>자료실</span>,
#  <span class="icon"></span>,
#  <span class="link"></span>,
#  <span class="icon"></span>,
#  <span class="pc_vw2">· KCGS</span>,
#  <span class="icon" onclick="$.layer_popup('#layer-noti-kcgs'); return false;">법적고지<i></i></span>,
#  <span class="text">ESG 평가문의(esg@cgs.or.kr), <br class="mo_vw2"/>등급 활용(esgdata@cgs.or.kr)</span>,
#  <span class="pc_vw2">· 한국 ESG 연구소</span>,
#  <span class="icon" onclick="$.layer_popup('#layer-noti-kesg'); return false;">법적고지<i></i></span>,
#  <span class="text">kresg@kesgresearch.com</span>,
#  <span class="pc_vw2">· Moody's</span>,
#  <span class="icon" onclick="$.layer_popup('#layer-noti-moodys'); return false;">법적고지<i></i></span>,
# ...

# %%
_list = []
for i in data_list :
    x = i.get_text()
    x = x.replace("\n", '')
    x = x.strip('\t')
    _list.append(x)
_list
# Out:
# ['{{com_abbrv}}{{yy}}{{key1}}{{key2}}',
#  'KCGS{{kcgs_esg}}',
#  '환경{{kcgs_env}}',
#  '사회{{kcgs_soc}}',
#  '지배구조{{kcgs_gov}}',
#  '한국ESG 연구소{{kesg_esg}}',
#  "Moody's{{moodys_esg}}",
#  'MSCI{{msci_esg}}',
#  'S&P{{sp_esg}}',
#  '',
#  '지속가능경영보고서 공시 여부',
#  'KCGS',
#  'S, A+, A, B+, B, C, D',
#  '한국ESG연구소',
#  'S, A+, A, B+, B, C, D',
#  "Moody's",
#  'Advanced(60점 이상), Robust(50~59점), Limited(30~49점), Weak(29점 이하)',
#  'MSCI',
#  'AAA, AA, A, BBB, BB, B, CCC',
#  'S&P',
#  '100~0']

# %% [markdown]
# > 다시!

# %%
url = "https://esg.krx.co.kr/contents/02/02020000/ESG02020000.jsp"
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

# %%
soup.find("")

# %%
df= pd.DataFrame()

# %%
pd.read_csv('../data/ESGdata/개별 ESG 데이터/2022.csv')
# Out:
#          기업명    기업코드 ESG등급  환경  사회 지배구조  평가년도
# 0     AJ네트웍스   95570    B+   C  B+   B+  2022
# 1      AK홀딩스    6840    B+   B   A    B  2022
# 2      AP시스템  265520     D   D   C    C  2022
# 3        BGF   27410    B+   A  A+    B  2022
# 4     BGF리테일  282330     A   A  A+    A  2022
# ...      ...     ...   ...  ..  ..  ...   ...
# 1000   현대홈쇼핑   57050     A   A  A+    A  2022
# 1001   형지엘리트   93240     D   D   C    D  2022
# 1002      혜인    3010     D   D   D    D  2022
# 1003    호전실업  111110     D   D   D    C  2022
# 1004    호텔신라    8770     A  B+   A    A  2022
#
# [1005 rows x 7 columns]

# %%
pd.read_csv('../data/ESGdata/업종분류데이터/2021코스피업종분류.csv', encoding='euc-kr', index_col='종목명')
# Out:
#            종목코드   시장구분    업종명      종가   대비   등락률           시가총액
# 종목명
# AJ네트웍스   095570  KOSPI   서비스업    5770  -70 -1.20   270164642150
# AK홀딩스    006840  KOSPI   기타금융   26800 -150 -0.56   355034634800
# BGF      027410  KOSPI   기타금융    5680 -300 -5.02   543671372880
# BGF리테일   282330  KOSPI    유통업  171000  500  0.29  2955547926000
# BNK금융지주  138930  KOSPI   기타금융    8810  -30 -0.34  2871489517260
# ...         ...    ...    ...     ...  ...   ...            ...
# 휴켐스      069260  KOSPI     화학   28250 -750 -2.59  1154820111000
# 흥국화재     000540  KOSPI     보험    3690  -80 -2.12   237055360050
# 흥국화재2우B  000547  KOSPI     보험   29200 -250 -0.85     4485120000
# 흥국화재우    000545  KOSPI     보험    8880 -510 -5.43     6819840000
# 흥아해운     003280  KOSPI  운수창고업    3785 -305 -7.46   905088230980
#
# [938 rows x 7 columns]

# %%
pd.read_csv('../data/ESGdata/업종분류데이터/2021코스닥업종분류.csv', encoding='euc-kr', index_col='종목명')
# Out:
#           종목코드    시장구분      업종명     종가   대비    등락률          시가총액
# 종목명
# 3S      060310  KOSDAQ    기계·장비   3960 -145  -3.53  183235191480
# APS홀딩스  054620  KOSDAQ       금융  16100 -300  -1.83  328346958100
# AP시스템   265520  KOSDAQ      반도체  24400 -550  -2.20  353317538800
# AP위성    211270  KOSDAQ     통신장비  17150 -450  -2.56  258661513600
# CBI     013720  KOSDAQ  운송장비·부품   3375  570  20.32  171104990625
# ...        ...     ...      ...    ...  ...    ...           ...
# 흥구석유    024060  KOSDAQ       유통   7830 -170  -2.13  117450000000
# 흥국      010240  KOSDAQ    기계·장비   8610 -470  -5.18  106098412560
# 흥국에프엔비  189980  KOSDAQ   음식료·담배   2975 -165  -5.25  114201702825
# 희림      037440  KOSDAQ    기타서비스   6310 -400  -5.96   87850817250
# 힘스      238490  KOSDAQ      반도체   8830 -140  -1.56   99887043880
#
# [1515 rows x 7 columns]

# %%
pd.read_csv('../data/ESGdata/업종분류데이터/2022코스피업종분류.csv', encoding='euc-kr', index_col='종목명')
# Out:
#            종목코드   시장구분    업종명      종가    대비   등락률           시가총액
# 종목명
# AJ네트웍스   095570  KOSPI   서비스업    7070   270  3.97   331033625650
# AK홀딩스    006840  KOSPI   기타금융   13350   100  0.75   176854939350
# BGF      027410  KOSPI   기타금융    3335    50  1.52   319215497985
# BGF리테일   282330  KOSPI    유통업  164000 -1500 -0.91  2834560584000
# BNK금융지주  138930  KOSPI   기타금융    6180   160  2.66  2014279820280
# ...         ...    ...    ...     ...   ...   ...            ...
# 휴스틸      005010  KOSPI   철강금속    5970   150  2.58   233952807750
# 흥국화재     000540  KOSPI     보험    3135    45  1.46   201400692075
# 흥국화재2우B  000547  KOSPI     보험   18100   300  1.69     2780160000
# 흥국화재우    000545  KOSPI     보험    6200   190  3.16     4761600000
# 흥아해운     003280  KOSPI  운수창고업    1250    20  1.63   300531123750
#
# [939 rows x 7 columns]

# %%
pd.read_csv('../data/ESGdata/업종분류데이터/2022코스닥업종분류.csv', encoding='euc-kr', index_col='종목명')
# Out:
#           종목코드    시장구분     업종명     종가    대비   등락률          시가총액
# 종목명
# 3S      060310  KOSDAQ   기계·장비   2340   125  5.64  108275340420
# APS홀딩스  054620  KOSDAQ      금융   9360   160  1.74  190889908560
# AP시스템   265520  KOSDAQ     반도체  17050  1150  7.23  260548228050
# AP위성    211270  KOSDAQ    통신장비   8940   240  2.76  134835797760
# BNGT    032790  KOSDAQ    정보기기   4075     0  0.00  120352455875
# ...        ...     ...     ...    ...   ...   ...           ...
# 흥구석유    024060  KOSDAQ      유통   5950   450  8.18   89250000000
# 흥국      010240  KOSDAQ   기계·장비   5230   260  5.23   64447700080
# 흥국에프엔비  189980  KOSDAQ  음식료·담배   2435    90  3.84   97394572385
# 희림      037440  KOSDAQ   기타서비스   7700   480  6.65  107203057500
# 힘스      238490  KOSDAQ     반도체   6710   410  6.51   75905103560
#
# [1586 rows x 7 columns]

# %%
pd.read_csv('../data/ESGdata/업종분류데이터/업종분류_2021.csv', index_col='종목명')
# Out:
#          Unnamed: 0    종목코드    시장구분     업종명      종가   대비   등락률           시가총액
# 종목명
# AJ네트웍스            0  095570   KOSPI    서비스업    5770  -70 -1.20   270164642150
# AK홀딩스             1  006840   KOSPI    기타금융   26800 -150 -0.56   355034634800
# BGF               2  027410   KOSPI    기타금융    5680 -300 -5.02   543671372880
# BGF리테일            3  282330   KOSPI     유통업  171000  500  0.29  2955547926000
# BNK금융지주           4  138930   KOSPI    기타금융    8810  -30 -0.34  2871489517260
# ...             ...     ...     ...     ...     ...  ...   ...            ...
# 흥구석유           1510  024060  KOSDAQ      유통    7830 -170 -2.13   117450000000
# 흥국             1511  010240  KOSDAQ   기계·장비    8610 -470 -5.18   106098412560
# 흥국에프엔비         1512  189980  KOSDAQ  음식료·담배    2975 -165 -5.25   114201702825
# 희림             1513  037440  KOSDAQ   기타서비스    6310 -400 -5.96    87850817250
# 힘스             1514  238490  KOSDAQ     반도체    8830 -140 -1.56    99887043880
#
# [2453 rows x 8 columns]

# %%
pd.read_csv('../data/ESGdata/업종분류데이터/업종분류_2022.csv', index_col='종목명')
# Out:
#          Unnamed: 0    종목코드    시장구분     업종명      종가    대비   등락률           시가총액
# 종목명
# AJ네트웍스            0  095570   KOSPI    서비스업    7070   270  3.97   331033625650
# AK홀딩스             1  006840   KOSPI    기타금융   13350   100  0.75   176854939350
# BGF               2  027410   KOSPI    기타금융    3335    50  1.52   319215497985
# BGF리테일            3  282330   KOSPI     유통업  164000 -1500 -0.91  2834560584000
# BNK금융지주           4  138930   KOSPI    기타금융    6180   160  2.66  2014279820280
# ...             ...     ...     ...     ...     ...   ...   ...            ...
# 흥구석유           1581  024060  KOSDAQ      유통    5950   450  8.18    89250000000
# 흥국             1582  010240  KOSDAQ   기계·장비    5230   260  5.23    64447700080
# 흥국에프엔비         1583  189980  KOSDAQ  음식료·담배    2435    90  3.84    97394572385
# 희림             1584  037440  KOSDAQ   기타서비스    7700   480  6.65   107203057500
# 힘스             1585  238490  KOSDAQ     반도체    6710   410  6.51    75905103560
#
# ...
